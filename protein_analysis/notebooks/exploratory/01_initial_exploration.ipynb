# %% [markdown]
# # Initial Data Exploration
# This notebook covers initial data exploration.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load data
df = pd.read_csv('../../data/raw/synthetic_protein_data.csv')
print(df.head())

# %%
# Basic statistics
print(df.describe())

# %%
# Plot distributions
df.hist(bins=20, figsize=(12, 10))
plt.tight_layout()
plt.show()
